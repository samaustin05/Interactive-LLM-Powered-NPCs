# %% [markdown]
# ### Create Public Vector Database

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_cohere import CohereEmbeddings
import json
import random
from langchain.vectorstores import Chroma

# Set the game name 
game_name = 'God_of_War_2018'

# Load the file
with open(f'{game_name}/public_info.txt', errors='ignore') as f:
    public_info = f.read()

# Randomly select an API key
selected_key = json.load(open('apikeys.json', 'r'))['api_keys'][random.randint(
    0, len(json.load(open('apikeys.json', 'r'))['api_keys'])-1)]

# Initialise the embedding model
embeddings = CohereEmbeddings(cohere_api_key=selected_key, model="large")

# Create Text Splitter, Chunk size is number of characters in each item of the list 
# While chunk overlap is how many characters from the previous item should be repeated in the next item 
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size = 1500,
    chunk_overlap  = 500,
    length_function = len,
    separators = ['\n\n\n', '\n\n', '\n', '.', ',', ' ']
)

# Split the text 
public_info_list = text_splitter.split_text(public_info)

# Path must be inside the game folder with the name public_vectordb
persist_directory = f'{game_name}/public_vectordb'

# Create the Vector Database
vectordb = Chroma.from_texts(public_info_list, embeddings, persist_directory=persist_directory)
vectordb.persist()
# Out:
# c:\Users\samau\OneDrive\Desktop\Interactive-LLM-Powered-NPCs\.venv\lib\site-packages\pydantic\_internal\_config.py:341: UserWarning: Valid config keys have changed in V2:
# * 'allow_population_by_field_name' has been renamed to 'populate_by_name'
# * 'smart_union' has been removed
#   warnings.warn(message, UserWarning)
# C:\Users\samau\AppData\Local\Temp\ipykernel_12476\3188708105.py:38: LangChainDeprecationWarning: Since Chroma 0.4.x the manual persistence method is no longer supported as docs are automatically persisted.
#   vectordb.persist()

# %%
# search for a topic and see if you get relevant information, k is for number of similar items to return
topic = "Atreus"
docs = vectordb.similarity_search(topic, k = 3)
similar_story_string = "\n".join(doc.page_content for doc in docs)
print(similar_story_string)
# Out:
# The Valkyries are among the most formidable foes in the game. These fallen warrior-maidens are imprisoned in corrupted physical forms, and defeating them is one of the gameâ€™s ultimate challenges. Each Valkyrie has a unique fighting style and set of attacks, testing the player's mastery of the combat system.
#
# As Kratos and Atreus journey through the realms, the game delves into themes of fatherhood, legacy, and redemption. Kratos, burdened by his past, struggles with the responsibility of raising Atreus, fearing that his son might inherit his own destructive tendencies. This fear manifests in Kratosâ€™ strictness and emotional distance, which he eventually learns to overcome as he grows closer to Atreus.
#
# The game also explores the idea of fate versus free will. The characters often grapple with prophecies and destinies that seem unavoidable, yet Kratos continuously seeks to forge his own path, resisting the notion that his or Atreus' futures are set in stone. This tension between accepting oneâ€™s destiny and fighting against it is a recurring motif, particularly as the shadow of Ragnarok looms over the story.
#
# Atreus' discovery of his true identity as Loki adds a layer of complexity to the narrative, raising questions about his role in the future events of the Norse pantheon. The revelation that Faye, his mother, was a giant who foresaw many of the events of the game, including Kratosâ€™ arrival in Midgard, underscores the interconnectedness of fate and choice.
# Story
# Many years have passed since the titular God of War, Kratos took his vengeance against the Olympian Gods. Having survived his final encounter with his father Zeus, Kratos has since travelled to Midgard in Ancient Norway and now lives with his young son Atreus in the Realm of the Norse Gods, a savage land inhabited by many ferocious monsters and warriors. In order to teach his son, whose mother (and Kratos' second wife) has recently died, how to survive in such a world, Kratos must master the rage that has driven him for many years and embrace his newfound role as a father and a mentor.
#
# Plot
#
# Delamain is an artificial intelligence that runs the taxi company known as the Delamain Corporation. Based in Night City, Delamain's core is found at its corp headquarters in Vista del Rey, Heywood.
#
# Dexter DeShawn, commonly known as Dex, was a well-known fixer in Night City. In 2077, he recently returned to the city after spending a few years off the grid. He has never personally worked as a mercenary before becoming a fixer, but had no need to thanks to his charisma and keen eye for potential.
# Johnny Silverhand and Kerry Eurodyne led the post-2008 resurgence of the genre with their band Samurai, and have made it onto the Top Ten. Since then, Rocker music has covered political, social, and economic activism. With the rise of cyberware, songs about technohumanism have found their way into the Rocker scene.[1]
#
# Sports
# The '93-'94 Super Bowl saw all pretense of "drug free" professional sports pushed aside, with six players dying in the game. During the collapse, professional sports died for over a decade. Violent blood sports became the norm amidst the chaos. Around roughly 2002, the military government formalized augmented sports. The great stadiums of the pre-Collapse largely disappeared save for the Arrowhead complex in Kansas City, or the Giants stadium in New York; and the "golden age" of professional sports was considered over; with the last Olympic Games held in 1992.

# %% [markdown]
# ### To add text to existing Public vector database
# #### (Optional, only if you want to add something that was not previously there in the above text file)

# %%
# from langchain.embeddings import CohereEmbeddings
# import json
# import random
# from langchain.vectorstores import Chroma

#selected_key = json.load(open('apikeys.json', 'r'))['api_keys'][random.randint(
#    0, len(json.load(open('apikeys.json', 'r'))['api_keys'])-1)]
#embeddings = CohereEmbeddings(cohere_api_key=selected_key)
#persist_directory = 'Cyberpunk_2077/public_vectordb'
#vectordb = Chroma(persist_directory=persist_directory, embedding_function=embeddings)
#vectordb.add_texts(["pineapples are yummy", "tomatoes are evil"])
#vectordb.persist()

# %% [markdown]
# #### To delete vectordb entirely, delete the public_vectordb folder inside the game folder

# %%
import shutil
# path to public_vectordb inside your game folder
folder_path = 'God_of_War_2018/public_vectordb'
shutil.rmtree(folder_path)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[6], line 4
#       2 # path to public_vectordb inside your game folder
#       3 folder_path = 'God_of_War_2018/public_vectordb'
# ----> 4 shutil.rmtree(folder_path)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\shutil.py:750, in rmtree(path, ignore_errors, onerror)
#     748     # can't continue even if onerror hook returns
#     749     return
# --> 750 return _rmtree_unsafe(path, onerror)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\shutil.py:615, in _rmtree_unsafe(path, onerror)
#     613         onerror(os.path.islink, fullname, sys.exc_info())
#     614         continue
# --> 615     _rmtree_unsafe(fullname, onerror)
#     616 else:
#     617     try:
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\shutil.py:620, in _rmtree_unsafe(path, onerror)
#     618             os.unlink(fullname)
#     619         except OSError:
# --> 620             onerror(os.unlink, fullname, sys.exc_info())
#     621 try:
#     622     os.rmdir(path)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\shutil.py:618, in _rmtree_unsafe(path, onerror)
#     616 else:
#     617     try:
# --> 618         os.unlink(fullname)
#     619     except OSError:
#     620         onerror(os.unlink, fullname, sys.exc_info())
#
# PermissionError: [WinError 32] The process cannot access the file because it is being used by another process: 'God_of_War_2018/public_vectordb\\aa7ee33a-25e3-4906-a879-f69adb1177a2\\data_level0.bin'
